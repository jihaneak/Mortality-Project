# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import sys
import os

# This adds the parent directory to your path so 'src' can be found
sys.path.append(os.path.abspath(os.path.join('..')))

from src.io import load_data
from src.bootstrap import bootstrap_life_expectancy
import numpy as np

# %%
import pandas as pd

# Load the main dataset
# Replace 'your_data_file.csv' with the actual path to your HMD data
df = load_data("../data/france_deaths_clean.csv", "../data/france_population_clean.csv")

# Now the line that was failing will work:
df_female_2020 = df[(df["Year"] == 2020) & (df["Sex"] == "Female")].copy()

# %%
df_female_2020 = df_female_2020.reset_index(drop=True)
df_female_2020["mx"] = df_female_2020["Deaths"] / df_female_2020["Exposure"]
samples = bootstrap_life_expectancy(
    df_female_2020,
    B=2000,
    ax=0.5
)

e0_mean = samples.mean()
ci = np.percentile(samples, [2.5, 97.5])

e0_mean, ci
# Out:
# (np.float64(85.09180670486163), array([85.05026974, 85.13282505]))
